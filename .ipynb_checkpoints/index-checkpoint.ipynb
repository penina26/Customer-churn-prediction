# %% [markdown]
# # Telecommunication company customer Churn Prediction
#
#
#
# ## Problem Description
# Customer churn is a term used when a customer decides to stop using the services of a business. Businesses do customer churn analysis most of the time because it helps them to know or learn which customers are about to leave.
#
# The aim of this project is to train a machine learning model on the available data that will predict with high accuracy which customers are about to churn, based on their behaviour which will in turn help the business owner in making useful marketing decisions for telco companies that hold subscription as one of their major KPI.
#
# The results of this analysis can be used to automate decision making in customer retention programs.
#
# ## Data Overview
#
# From source:
#  https://community.ibm.com/community/user/businessanalytics/blogs/steven-macko/2019/07/11/telco-customer-churn-1113
#
# The Telco customer churn data contains information about a fictional telco company that provided home phone and Internet services to 7032 customers in California in Q3. It indicates which customers have left, stayed, or signed up for their service. Multiple important demographics are included for each customer, as well as a Satisfaction Score, Churn Score, and Customer Lifetime Value (CLTV) index.
#
# The training dataset contains 7032 samples. Each sample contains 21 features and 1 Boolean variable “churn” which indicates the class of the sample. The 20 input features and 1 target variable are:
#
#
# 1. customerID - unique value identifying customer
# 2. gender - whether the customer is a male or a female
# 3. SeniorCitizen - whether the customer is a senior citizen or not (1, 0)
# 4. Partner - whether the customer has a partner or not (Yes, No)
# 5. Dependents - whether the customer has dependents or not (Yes, No). A dependent is a person who relies on another as a primary source of income,
# 6. tenure - number of months the customer has stayed with the company
# 7. PhoneService - whether the customer has a phone service or not (Yes, No)
# 8. MultipleLines - whether the customer has multiple lines or not (Yes, No, No phone service)
# 9. InternetService - customer’s internet service provider (DSL, Fiber optic, No)
# 10. OnlineSecurity - whether the customer has online security or not (Yes, No, No internet service)
# 11. OnlineBackup - whether the customer has online backup or not (Yes, No, No internet service)
# 12. DeviceProtection - whether the customer has device protection or not (Yes, No, No internet service)
# 13.	TechSupport - whether the customer has tech support or not (Yes, No, No internet service)
# 14.	StreamingTV - whether the customer has streaming TV or not (Yes, No, No internet service)
# 15.	StreamingMovies - whether the customer has streaming movies or not (Yes, No, No internet service)
# 16.	Contract - type of contract according to duration (Month-to-month, One year, Two year)
# 17.	PaperlessBilling - bills issued in paperless form (Yes, No)
# 18.	PaymentMethod - payment method used by customer (Electronic check, Mailed check, Credit card (automatic), Bank transfer (automatic))
# 19.	MonthlyCharges - amount of charge for service on monthly bases
# 20.	TotalCharges - cumulative charges for service during subscription (tenure) period
# 21.	 Churn  - variable we are trying to predict or estimate
#
#
#
# ## Metric of Success
#
# * High Accuracy is needed
# * Since we are dealing with an imbalanced dataset,we will keep track of the Recall and confusion matrix
#
# * **Accuracy** = Number of correctly predited test samples/Total number of test sample
#
#
# * **Recall** = True Positives/ (True positive + False negatives)

# %% [markdown]
# ## 1.0 Data Preparation

# %% [markdown]
# ### Load the Dataset using Pandas

# %%
#import pandas to load the data
import pandas as pd
#import numpy for mathematical calculations
import numpy as np
#import matplotlib for visualization
import matplotlib.pyplot as plt
#set %matplotlib inline so the graphs will display immediately below the cell that creates them
# %matplotlib inline
#import seaborn for visualization
import seaborn as sns
#use ggplot for styling
plt.style.use('ggplot')
#ignore warnings
import warnings
warnings.filterwarnings('ignore')
from sklearn.metrics import plot_confusion_matrix, classification_report,accuracy_score

#load the dataset
df = pd.read_csv('Telco-Customer-Churn.csv')

# %%
#make a copy of the dataset
data = df.copy()
#preview the dataset
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges  Churn
# 0           Electronic check          29.85         29.85     No
# 1               Mailed check          56.95       1889.50     No
# 2               Mailed check          53.85        108.15    Yes
# 3  Bank transfer (automatic)          42.30       1840.75     No
# 4           Electronic check          70.70        151.65    Yes
#
# [5 rows x 21 columns]

# %% [markdown]
# #### Check the general structure of the dataset i.e datatypes, shape, summary statistics

# %%
#check the the datatypes and meta data for data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7032 entries, 0 to 7031
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7032 non-null   object
#  1   gender            7032 non-null   object
#  2   SeniorCitizen     7032 non-null   int64
#  3   Partner           7032 non-null   object
#  4   Dependents        7032 non-null   object
#  5   tenure            7032 non-null   int64
#  6   PhoneService      7032 non-null   object
#  7   MultipleLines     7032 non-null   object
#  8   InternetService   7032 non-null   object
#  9   OnlineSecurity    7032 non-null   object
#  10  OnlineBackup      7032 non-null   object
#  11  DeviceProtection  7032 non-null   object
#  12  TechSupport       7032 non-null   object
#  13  StreamingTV       7032 non-null   object
#  14  StreamingMovies   7032 non-null   object
#  15  Contract          7032 non-null   object
#  16  PaperlessBilling  7032 non-null   object
#  17  PaymentMethod     7032 non-null   object
#  18  MonthlyCharges    7032 non-null   float64
#  19  TotalCharges      7032 non-null   float64
#  20  Churn             7032 non-null   object
# dtypes: float64(2), int64(2), object(17)
# memory usage: 1.1+ MB

# %%
#we notice that the of the colums are of type object. Only 4 are of type integer and float

# %%
#check the shape of the dataset
data.shape
# Out:
# (7032, 21)

# %%
#our dataset has 7032 rows and 21 columns

# %%
#check the summary statics of the dataset
data.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7032.000000  7032.000000     7032.000000   7032.000000
# mean        0.162400    32.421786       64.798208   2283.300441
# std         0.368844    24.545260       30.085974   2266.771362
# min         0.000000     1.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.587500    401.450000
# 50%         0.000000    29.000000       70.350000   1397.475000
# 75%         0.000000    55.000000       89.862500   3794.737500
# max         1.000000    72.000000      118.750000   8684.800000

# %%
#Only "SeniorCitizen", "tenure" , "	TotalCharges" and "MonthlyCharges" are assigned to numeric data types.This is not machine laerning friendly and 
#will need to convert them

# %% [markdown]
# #### Data Cleaning

# %%
#check for null entries
data.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
#our data set doesnt contain any null values

# %%
#check for duplicates
df.duplicated(subset=['customerID']).sum()
# Out:
# 0

# %%
#our data doesnt contain duplicate values

# %% [markdown]
# ### Data Transformation

# %% [markdown]
# #### Convert Categorical variables to numeric dummies using pandas

# %%
#lets drop the customer id from the dataset as it doesnt have any more use now
data.drop('customerID', axis=1, inplace=True)
#select categirical data = data.select
categoricals = data.select_dtypes(include=['object'])

# %%
#convert to numerics, inclue drop_first = True to aviod multicollinaerity
categoricals_to_num = pd.get_dummies(categoricals, drop_first=True)

# %%
numericals = data.select_dtypes(exclude=['object'])

# %%
#combine numeric features and the dummy numeric features
data_transformed = pd.concat([numericals, categoricals_to_num], axis=1)

# %%
#confirm the combining correctly
data_transformed.sample(5)
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges  gender_Male  \
# 5317              0      15           20.00        288.05            1
# 3053              0      17           55.85        937.50            0
# 6347              0      10           98.90       1064.95            1
# 129               1      71           56.45       3985.35            1
# 5604              0      72           70.45       5165.70            0
#
#       Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 5317            1               1                 1
# 3053            0               1                 1
# 6347            0               0                 1
# 129             0               0                 0
# 5604            1               1                 1
#
#       MultipleLines_No phone service  MultipleLines_Yes  ...  StreamingTV_Yes  \
# 5317                               0                  0  ...                0
# 3053                               0                  1  ...                0
# 6347                               0                  0  ...                1
# 129                                1                  0  ...                1
# 5604                               0                  1  ...                0
#
#       StreamingMovies_No internet service  StreamingMovies_Yes  \
# 5317                                    1                    0
# 3053                                    0                    0
# 6347                                    0                    1
# 129                                     0                    1
# 5604                                    0                    0
#
#       Contract_One year  Contract_Two year  PaperlessBilling_Yes  \
# 5317                  0                  0                     1
# 3053                  1                  0                     1
# 6347                  1                  0                     1
# 129                   1                  0                     1
# 5604                  0                  1                     1
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 5317                                      0                               1
# 3053                                      0                               0
# 6347                                      0                               1
# 129                                       0                               1
# 5604                                      0                               0
#
#       PaymentMethod_Mailed check  Churn_Yes
# 5317                           0          1
# 3053                           1          1
# 6347                           0          0
# 129                            0          0
# 5604                           0          0
#
# [5 rows x 31 columns]

# %% [markdown]
# ## 2.0 Exploratory Data Analysis
# Here we will plot a few visualizations to see how our data looks like graphically

# %% [markdown]
# ### Univariate
# Here we look at how our target variable is class is distributed

# %%
#check for percentage distribution of the churn class
data_transformed['Churn_Yes'].value_counts(normalize=True)
# Out:
# 0    0.734215
# 1    0.265785
# Name: Churn_Yes, dtype: float64

# %%
sns.countplot(data=data_transformed, x='Churn_Yes')
plt.title('Customers Churned v/s Not Churned');

# %%
#there is a class imbalance issue as depicted from the above plot.73.42% of the data represnts customers who did not churn and  26.58% represents customers who churned

# %% [markdown]
# **Check for correlation of predictor features to the class label by plotting barplot. For the categorical features, we will need to convert them into dummy variables first, as we can only calculate correlation for numeric features.**

# %%
#inspect the correlation of fetures to churn
corr_df = data_transformed.corr()
#leave out the 0 values i.e not churn
corr_yes_churn = corr_df['Churn_Yes'].sort_values().iloc[1:-1]
corr_yes_churn
# Out:
# Contract_Two year                       -0.301552
# OnlineSecurity_No internet service      -0.227578
# StreamingMovies_No internet service     -0.227578
# StreamingTV_No internet service         -0.227578
# TechSupport_No internet service         -0.227578
# DeviceProtection_No internet service    -0.227578
# OnlineBackup_No internet service        -0.227578
# InternetService_No                      -0.227578
# TotalCharges                            -0.199484
# Contract_One year                       -0.178225
# OnlineSecurity_Yes                      -0.171270
# TechSupport_Yes                         -0.164716
# Dependents_Yes                          -0.163128
# Partner_Yes                             -0.149982
# PaymentMethod_Credit card (automatic)   -0.134687
# PaymentMethod_Mailed check              -0.090773
# OnlineBackup_Yes                        -0.082307
# DeviceProtection_Yes                    -0.066193
# MultipleLines_No phone service          -0.011691
# gender_Male                             -0.008545
# PhoneService_Yes                         0.011691
# MultipleLines_Yes                        0.040033
# StreamingMovies_Yes                      0.060860
# StreamingTV_Yes                          0.063254
# SeniorCitizen                            0.150541
# PaperlessBilling_Yes                     0.191454
# MonthlyCharges                           0.192858
# PaymentMethod_Electronic check           0.301455
# InternetService_Fiber optic              0.307463
# Name: Churn_Yes, dtype: float64

# %%
#plot a bar plot on the series created above
plt.figure(figsize=(10,4))
sns.barplot(x=corr_yes_churn.index, y=corr_yes_churn.values)
plt.title("Feature Correlation with YES Churn")
plt.xticks(rotation=90);

# %%
#From the visualization we see that (Contract_Two year                       -0.301552
# OnlineSecurity_No internet service      -0.227578
# StreamingMovies_No internet service     -0.227578
# StreamingTV_No internet service         -0.227578
# TechSupport_No internet service         -0.227578
# DeviceProtection_No internet service    -0.227578
# OnlineBackup_No internet service        -0.227578
# InternetService_No                      -0.227578
# TotalCharges                            -0.199484
# Contract_One year                       -0.178225
# OnlineSecurity_Yes                      -0.171270
# TechSupport_Yes                         -0.164716
# Dependents_Yes                          -0.163128
# Partner_Yes                             -0.149982
# PaymentMethod_Credit card (automatic)   -0.134687
# PaymentMethod_Mailed check              -0.090773
# OnlineBackup_Yes                        -0.082307
# DeviceProtection_Yes                    -0.066193
# MultipleLines_No phone service          -0.011691
# gender_Male                             
# ) have a negative correlation to churning while (
# PhoneService_Yes                         0.011691
# MultipleLines_Yes                        0.040033
# StreamingMovies_Yes                      0.060860
# StreamingTV_Yes                          0.063254
# SeniorCitizen                            0.150541
# PaperlessBilling_Yes                     0.191454
# MonthlyCharges                           0.192858
# PaymentMethod_Electronic check           0.301455
# InternetService_Fiber optic              
# ) have a postive correlaion with churning

# %% [markdown]
# ### check the distribution of positively conreltaed features with a hue of churn

# %%
postive_corr_feat = ['PhoneService_Yes','MultipleLines_Yes', 'StreamingMovies_Yes','SeniorCitizen','PaperlessBilling_Yes',
                     'MonthlyCharges','PaymentMethod_Electronic check','InternetService_Fiber optic']

# %% [markdown]
# **Explore the distrbution of TotalCharges between Churn categories with a boxplot.**

# %%
sns.boxplot(data=data_transformed, x='Churn_Yes', y='TotalCharges');

# %%
#we notice that the 'yes' churn class has some outliers, with an vaerage total charges of about 1000, 
#while the 'No' class has no outliers with an average total charge of about 1800

# %% [markdown]
# **Boxplot showing the distribution of TotalCharges per Contract type, with a hue coloring based on the Churn class.**

# %%
plt.figure(figsize=(10,4))
sns.boxplot(data=data_transformed, x='Contract_One year', y='TotalCharges', hue='Churn_Yes');
plt.legend(loc=(1.05,0.5));
plt.tight_layout()

# %%
#from the above plot, we see that there is very little difference in terms of charges for the people with Month-to-Month Contarct
#there is however a noticeable difference for the people with contracts of one or two years. The people who chhurn out are charged highly

# %% [markdown]
# ## check the distribution of InternetService with a hue of churn

# %%
df['InternetService'].value_counts()
sns.countplot(data=data_transformed, x='InternetService_Fiber optic', hue='Churn_Yes');

# %%
#its noted that most people who churn out use Fibre Optic Internet service

# %% [markdown]
# ## check the churn pattern for Internet service in relation to contract type
# Does A company's tech support influence customer retention?

# %%
sns.catplot(data=data_transformed, x = 'InternetService_Fiber optic', hue='Churn_Yes', kind='count', 
           col='Contract_One year');

# %%
#its noted that customers who use the internet service of type fibre optic and on month to month contract have a quite high churning rate compared to 
#DSL and those who do not use the internet.
#Generally most customers who use intrernet service are on month-to-month contract

# %% [markdown]
# ## check the distribution of TechSupport with a hue of churn
# Does a company's tech support influence customer retention?

# %%
sns.catplot(data=data_transformed, x = 'TechSupport_Yes', hue='Churn_Yes', kind='count', 
           col='InternetService_Fiber optic');

# %%
#its noted that customers who are not subscribed to Fiber optic internet service dont churn out alot  eveb when they dont receive  Techsupport

# %% [markdown]
# **Check citizen Seniority in relation to churning**

# %%
sns.countplot(data=data_transformed, x='SeniorCitizen', hue='Churn_Yes');

# %%
#most people who churn out of the service are not senior citizens

# %% [markdown]
# **Check the number of contract types available**

# %%
sns.histplot(data=df, x='tenure', bins=60);

# %%
#most customers stay on for one to 2 months
# We also have many customesrs who have stayed for more than 70 months
#Other customers are just in between 10-65 months

# %% [markdown]
# **A histogram showing the number of Churns based on the Contract type and the number of months they have been subscribers.**

# %%
sns.displot(data=data_transformed, x='tenure', bins=70, col='Contract_One year', row='Churn_Yes');

# %%
#from the above plot, we see that most people who churn out are on less than one year contract.
#maybe we could ask the company to look for ways of encouraging people on month-to-month contract to stay longer
# We also notice that there are people who have stayed for more than 10 months and are still on less than one year contract
#could this be because of higher charges?

# %% [markdown]
# **Display a scatter plot of Total Charges versus Monthly Charges, and color hue by Churn.**

# %%
plt.figure(figsize=(10,4), dpi=200)
sns.scatterplot(data=df, x='MonthlyCharges', y='TotalCharges', hue='Churn',
               alpha=0.4, linewidth=0.3);

# %%
#We can see that a lot of people tend to churn when their Monthly charges are higher
#even though there isnt match of total charges

# %% [markdown]
# ### Get the percentage churn (churn rate) based on the tenure
# **We will begin by grouping the data by churn and tenure then calculate the percentage by dividing the yes churn group bt the
# total of yes churn and no churn the multiply by 100**

# %%
#get the yes churn group based on the count 
#transpose the dataframe for easy reading and grabbing the yes class
yes_churn = data_transformed.groupby(['Churn_Yes', 'tenure']).count().transpose()[1]
yes_churn
# Out:
# tenure                                  1    2   3   4   5   6   7   8   9   \
# SeniorCitizen                          380  123  94  83  64  40  51  42  46
# MonthlyCharges                         380  123  94  83  64  40  51  42  46
# TotalCharges                           380  123  94  83  64  40  51  42  46
# gender_Male                            380  123  94  83  64  40  51  42  46
# Partner_Yes                            380  123  94  83  64  40  51  42  46
# Dependents_Yes                         380  123  94  83  64  40  51  42  46
# PhoneService_Yes                       380  123  94  83  64  40  51  42  46
# MultipleLines_No phone service         380  123  94  83  64  40  51  42  46
# MultipleLines_Yes                      380  123  94  83  64  40  51  42  46
# InternetService_Fiber optic            380  123  94  83  64  40  51  42  46
# InternetService_No                     380  123  94  83  64  40  51  42  46
# OnlineSecurity_No internet service     380  123  94  83  64  40  51  42  46
# OnlineSecurity_Yes                     380  123  94  83  64  40  51  42  46
# OnlineBackup_No internet service       380  123  94  83  64  40  51  42  46
# OnlineBackup_Yes                       380  123  94  83  64  40  51  42  46
# DeviceProtection_No internet service   380  123  94  83  64  40  51  42  46
# DeviceProtection_Yes                   380  123  94  83  64  40  51  42  46
# TechSupport_No internet service        380  123  94  83  64  40  51  42  46
# TechSupport_Yes                        380  123  94  83  64  40  51  42  46
# StreamingTV_No internet service        380  123  94  83  64  40  51  42  46
# StreamingTV_Yes                        380  123  94  83  64  40  51  42  46
# StreamingMovies_No internet service    380  123  94  83  64  40  51  42  46
# StreamingMovies_Yes                    380  123  94  83  64  40  51  42  46
# Contract_One year                      380  123  94  83  64  40  51  42  46
# Contract_Two year                      380  123  94  83  64  40  51  42  46
# PaperlessBilling_Yes                   380  123  94  83  64  40  51  42  46
# PaymentMethod_Credit card (automatic)  380  123  94  83  64  40  51  42  46
# PaymentMethod_Electronic check         380  123  94  83  64  40  51  42  46
# PaymentMethod_Mailed check             380  123  94  83  64  40  51  42  46
#
# tenure                                 10  ...  63  64  65  66  67  68  69  \
# SeniorCitizen                          45  ...   4   4   9  13  10   9   8
# MonthlyCharges                         45  ...   4   4   9  13  10   9   8
# TotalCharges                           45  ...   4   4   9  13  10   9   8
# gender_Male                            45  ...   4   4   9  13  10   9   8
# Partner_Yes                            45  ...   4   4   9  13  10   9   8
# Dependents_Yes                         45  ...   4   4   9  13  10   9   8
# PhoneService_Yes                       45  ...   4   4   9  13  10   9   8
# MultipleLines_No phone service         45  ...   4   4   9  13  10   9   8
# MultipleLines_Yes                      45  ...   4   4   9  13  10   9   8
# InternetService_Fiber optic            45  ...   4   4   9  13  10   9   8
# InternetService_No                     45  ...   4   4   9  13  10   9   8
# OnlineSecurity_No internet service     45  ...   4   4   9  13  10   9   8
# OnlineSecurity_Yes                     45  ...   4   4   9  13  10   9   8
# OnlineBackup_No internet service       45  ...   4   4   9  13  10   9   8
# OnlineBackup_Yes                       45  ...   4   4   9  13  10   9   8
# DeviceProtection_No internet service   45  ...   4   4   9  13  10   9   8
# DeviceProtection_Yes                   45  ...   4   4   9  13  10   9   8
# TechSupport_No internet service        45  ...   4   4   9  13  10   9   8
# TechSupport_Yes                        45  ...   4   4   9  13  10   9   8
# StreamingTV_No internet service        45  ...   4   4   9  13  10   9   8
# StreamingTV_Yes                        45  ...   4   4   9  13  10   9   8
# StreamingMovies_No internet service    45  ...   4   4   9  13  10   9   8
# StreamingMovies_Yes                    45  ...   4   4   9  13  10   9   8
# Contract_One year                      45  ...   4   4   9  13  10   9   8
# Contract_Two year                      45  ...   4   4   9  13  10   9   8
# PaperlessBilling_Yes                   45  ...   4   4   9  13  10   9   8
# PaymentMethod_Credit card (automatic)  45  ...   4   4   9  13  10   9   8
# PaymentMethod_Electronic check         45  ...   4   4   9  13  10   9   8
# PaymentMethod_Mailed check             45  ...   4   4   9  13  10   9   8
#
# tenure                                 70  71  72
# SeniorCitizen                          11   6   6
# MonthlyCharges                         11   6   6
# TotalCharges                           11   6   6
# gender_Male                            11   6   6
# Partner_Yes                            11   6   6
# Dependents_Yes                         11   6   6
# PhoneService_Yes                       11   6   6
# MultipleLines_No phone service         11   6   6
# MultipleLines_Yes                      11   6   6
# InternetService_Fiber optic            11   6   6
# InternetService_No                     11   6   6
# OnlineSecurity_No internet service     11   6   6
# OnlineSecurity_Yes                     11   6   6
# OnlineBackup_No internet service       11   6   6
# OnlineBackup_Yes                       11   6   6
# DeviceProtection_No internet service   11   6   6
# DeviceProtection_Yes                   11   6   6
# TechSupport_No internet service        11   6   6
# TechSupport_Yes                        11   6   6
# StreamingTV_No internet service        11   6   6
# StreamingTV_Yes                        11   6   6
# StreamingMovies_No internet service    11   6   6
# StreamingMovies_Yes                    11   6   6
# Contract_One year                      11   6   6
# Contract_Two year                      11   6   6
# PaperlessBilling_Yes                   11   6   6
# PaymentMethod_Credit card (automatic)  11   6   6
# PaymentMethod_Electronic check         11   6   6
# PaymentMethod_Mailed check             11   6   6
#
# [29 rows x 72 columns]

# %%
#get the no churn group 
#transpose the dataframe for easy reading and grabbing the no class
no_churn = data_transformed.groupby(['Churn_Yes', 'tenure']).count().transpose()[0]
no_churn
# Out:
# tenure                                  1    2    3   4   5   6   7   8   9   \
# SeniorCitizen                          233  115  106  93  69  70  80  81  73
# MonthlyCharges                         233  115  106  93  69  70  80  81  73
# TotalCharges                           233  115  106  93  69  70  80  81  73
# gender_Male                            233  115  106  93  69  70  80  81  73
# Partner_Yes                            233  115  106  93  69  70  80  81  73
# Dependents_Yes                         233  115  106  93  69  70  80  81  73
# PhoneService_Yes                       233  115  106  93  69  70  80  81  73
# MultipleLines_No phone service         233  115  106  93  69  70  80  81  73
# MultipleLines_Yes                      233  115  106  93  69  70  80  81  73
# InternetService_Fiber optic            233  115  106  93  69  70  80  81  73
# InternetService_No                     233  115  106  93  69  70  80  81  73
# OnlineSecurity_No internet service     233  115  106  93  69  70  80  81  73
# OnlineSecurity_Yes                     233  115  106  93  69  70  80  81  73
# OnlineBackup_No internet service       233  115  106  93  69  70  80  81  73
# OnlineBackup_Yes                       233  115  106  93  69  70  80  81  73
# DeviceProtection_No internet service   233  115  106  93  69  70  80  81  73
# DeviceProtection_Yes                   233  115  106  93  69  70  80  81  73
# TechSupport_No internet service        233  115  106  93  69  70  80  81  73
# TechSupport_Yes                        233  115  106  93  69  70  80  81  73
# StreamingTV_No internet service        233  115  106  93  69  70  80  81  73
# StreamingTV_Yes                        233  115  106  93  69  70  80  81  73
# StreamingMovies_No internet service    233  115  106  93  69  70  80  81  73
# StreamingMovies_Yes                    233  115  106  93  69  70  80  81  73
# Contract_One year                      233  115  106  93  69  70  80  81  73
# Contract_Two year                      233  115  106  93  69  70  80  81  73
# PaperlessBilling_Yes                   233  115  106  93  69  70  80  81  73
# PaymentMethod_Credit card (automatic)  233  115  106  93  69  70  80  81  73
# PaymentMethod_Electronic check         233  115  106  93  69  70  80  81  73
# PaymentMethod_Mailed check             233  115  106  93  69  70  80  81  73
#
# tenure                                 10  ...  63  64  65  66  67  68  69  \
# SeniorCitizen                          71  ...  68  76  67  76  88  91  87
# MonthlyCharges                         71  ...  68  76  67  76  88  91  87
# TotalCharges                           71  ...  68  76  67  76  88  91  87
# gender_Male                            71  ...  68  76  67  76  88  91  87
# Partner_Yes                            71  ...  68  76  67  76  88  91  87
# Dependents_Yes                         71  ...  68  76  67  76  88  91  87
# PhoneService_Yes                       71  ...  68  76  67  76  88  91  87
# MultipleLines_No phone service         71  ...  68  76  67  76  88  91  87
# MultipleLines_Yes                      71  ...  68  76  67  76  88  91  87
# InternetService_Fiber optic            71  ...  68  76  67  76  88  91  87
# InternetService_No                     71  ...  68  76  67  76  88  91  87
# OnlineSecurity_No internet service     71  ...  68  76  67  76  88  91  87
# OnlineSecurity_Yes                     71  ...  68  76  67  76  88  91  87
# OnlineBackup_No internet service       71  ...  68  76  67  76  88  91  87
# OnlineBackup_Yes                       71  ...  68  76  67  76  88  91  87
# DeviceProtection_No internet service   71  ...  68  76  67  76  88  91  87
# DeviceProtection_Yes                   71  ...  68  76  67  76  88  91  87
# TechSupport_No internet service        71  ...  68  76  67  76  88  91  87
# TechSupport_Yes                        71  ...  68  76  67  76  88  91  87
# StreamingTV_No internet service        71  ...  68  76  67  76  88  91  87
# StreamingTV_Yes                        71  ...  68  76  67  76  88  91  87
# StreamingMovies_No internet service    71  ...  68  76  67  76  88  91  87
# StreamingMovies_Yes                    71  ...  68  76  67  76  88  91  87
# Contract_One year                      71  ...  68  76  67  76  88  91  87
# Contract_Two year                      71  ...  68  76  67  76  88  91  87
# PaperlessBilling_Yes                   71  ...  68  76  67  76  88  91  87
# PaymentMethod_Credit card (automatic)  71  ...  68  76  67  76  88  91  87
# PaymentMethod_Electronic check         71  ...  68  76  67  76  88  91  87
# PaymentMethod_Mailed check             71  ...  68  76  67  76  88  91  87
#
# tenure                                  70   71   72
# SeniorCitizen                          108  164  356
# MonthlyCharges                         108  164  356
# TotalCharges                           108  164  356
# gender_Male                            108  164  356
# Partner_Yes                            108  164  356
# Dependents_Yes                         108  164  356
# PhoneService_Yes                       108  164  356
# MultipleLines_No phone service         108  164  356
# MultipleLines_Yes                      108  164  356
# InternetService_Fiber optic            108  164  356
# InternetService_No                     108  164  356
# OnlineSecurity_No internet service     108  164  356
# OnlineSecurity_Yes                     108  164  356
# OnlineBackup_No internet service       108  164  356
# OnlineBackup_Yes                       108  164  356
# DeviceProtection_No internet service   108  164  356
# DeviceProtection_Yes                   108  164  356
# TechSupport_No internet service        108  164  356
# TechSupport_Yes                        108  164  356
# StreamingTV_No internet service        108  164  356
# StreamingTV_Yes                        108  164  356
# StreamingMovies_No internet service    108  164  356
# StreamingMovies_Yes                    108  164  356
# Contract_One year                      108  164  356
# Contract_Two year                      108  164  356
# PaperlessBilling_Yes                   108  164  356
# PaymentMethod_Credit card (automatic)  108  164  356
# PaymentMethod_Electronic check         108  164  356
# PaymentMethod_Mailed check             108  164  356
#
# [29 rows x 72 columns]

# %%
#calculate the percentage of people that churned
churn_rate = 100 * yes_churn/(yes_churn + no_churn)
churn_rate.transpose()
# Out:
#         SeniorCitizen  MonthlyCharges  TotalCharges  gender_Male  Partner_Yes  \
# tenure
# 1           61.990212       61.990212     61.990212    61.990212    61.990212
# 2           51.680672       51.680672     51.680672    51.680672    51.680672
# 3           47.000000       47.000000     47.000000    47.000000    47.000000
# 4           47.159091       47.159091     47.159091    47.159091    47.159091
# 5           48.120301       48.120301     48.120301    48.120301    48.120301
# ...               ...             ...           ...          ...          ...
# 68           9.000000        9.000000      9.000000     9.000000     9.000000
# 69           8.421053        8.421053      8.421053     8.421053     8.421053
# 70           9.243697        9.243697      9.243697     9.243697     9.243697
# 71           3.529412        3.529412      3.529412     3.529412     3.529412
# 72           1.657459        1.657459      1.657459     1.657459     1.657459
#
#         Dependents_Yes  PhoneService_Yes  MultipleLines_No phone service  \
# tenure
# 1            61.990212         61.990212                       61.990212
# 2            51.680672         51.680672                       51.680672
# 3            47.000000         47.000000                       47.000000
# 4            47.159091         47.159091                       47.159091
# 5            48.120301         48.120301                       48.120301
# ...                ...               ...                             ...
# 68            9.000000          9.000000                        9.000000
# 69            8.421053          8.421053                        8.421053
# 70            9.243697          9.243697                        9.243697
# 71            3.529412          3.529412                        3.529412
# 72            1.657459          1.657459                        1.657459
#
#         MultipleLines_Yes  InternetService_Fiber optic  ...  \
# tenure                                                  ...
# 1               61.990212                    61.990212  ...
# 2               51.680672                    51.680672  ...
# 3               47.000000                    47.000000  ...
# 4               47.159091                    47.159091  ...
# 5               48.120301                    48.120301  ...
# ...                   ...                          ...  ...
# 68               9.000000                     9.000000  ...
# 69               8.421053                     8.421053  ...
# 70               9.243697                     9.243697  ...
# 71               3.529412                     3.529412  ...
# 72               1.657459                     1.657459  ...
#
#         StreamingTV_No internet service  StreamingTV_Yes  \
# tenure
# 1                             61.990212        61.990212
# 2                             51.680672        51.680672
# 3                             47.000000        47.000000
# 4                             47.159091        47.159091
# 5                             48.120301        48.120301
# ...                                 ...              ...
# 68                             9.000000         9.000000
# 69                             8.421053         8.421053
# 70                             9.243697         9.243697
# 71                             3.529412         3.529412
# 72                             1.657459         1.657459
#
#         StreamingMovies_No internet service  StreamingMovies_Yes  \
# tenure
# 1                                 61.990212            61.990212
# 2                                 51.680672            51.680672
# 3                                 47.000000            47.000000
# 4                                 47.159091            47.159091
# 5                                 48.120301            48.120301
# ...                                     ...                  ...
# 68                                 9.000000             9.000000
# 69                                 8.421053             8.421053
# 70                                 9.243697             9.243697
# 71                                 3.529412             3.529412
# 72                                 1.657459             1.657459
#
#         Contract_One year  Contract_Two year  PaperlessBilling_Yes  \
# tenure
# 1               61.990212          61.990212             61.990212
# 2               51.680672          51.680672             51.680672
# 3               47.000000          47.000000             47.000000
# 4               47.159091          47.159091             47.159091
# 5               48.120301          48.120301             48.120301
# ...                   ...                ...                   ...
# 68               9.000000           9.000000              9.000000
# 69               8.421053           8.421053              8.421053
# 70               9.243697           9.243697              9.243697
# 71               3.529412           3.529412              3.529412
# 72               1.657459           1.657459              1.657459
#
#         PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# tenure
# 1                                   61.990212                       61.990212
# 2                                   51.680672                       51.680672
# 3                                   47.000000                       47.000000
# 4                                   47.159091                       47.159091
# 5                                   48.120301                       48.120301
# ...                                       ...                             ...
# 68                                   9.000000                        9.000000
# 69                                   8.421053                        8.421053
# 70                                   9.243697                        9.243697
# 71                                   3.529412                        3.529412
# 72                                   1.657459                        1.657459
#
#         PaymentMethod_Mailed check
# tenure
# 1                        61.990212
# 2                        51.680672
# 3                        47.000000
# 4                        47.159091
# 5                        48.120301
# ...                            ...
# 68                        9.000000
# 69                        8.421053
# 70                        9.243697
# 71                        3.529412
# 72                        1.657459
#
# [72 rows x 29 columns]

# %%
#transpose the churn_rate for readability, and easy feature selection
#check the churn rate base of off SeniorCitizen count, its the saame accross the board. Another column could be used
#then plot the churn rate
churn_rate.transpose()['SeniorCitizen'].plot(figsize=(10,4))
plt.title("Churn rate based on customer's Tenure");

# %%
#we notice that people with less tenure tend to churn out a lot.

# %% [markdown]
# # 4.0 Feature Engineering
#
# ### Create broader sections that groups the tenure of a  customer into below units  and assign it to a new column Tenure Cohort
#    * '0-12 Months'
#    * '12-24 Months'
#    * '24-48 Months'
#    * 'Over 48 Months'

# %%
#create a funtion for grouping people's tenures
def cohort(tenure):
    if tenure < 13:
        return '0-12 Months'
    elif tenure >12 and tenure < 25:
        return '12-24 Months'
    elif tenure >24 and tenure < 48:
        return '24-48 Months'
    else:
        return 'Over 48 Months'

# %%
#create a new column based on the tenure column
data_transformed['Tenure Cohort'] = data_transformed['tenure'].apply(cohort)

# %%
#preview the df[Tenure cohort]
data_transformed['Tenure Cohort'].sample(4)
# Out:
# 5047    Over 48 Months
# 4943      24-48 Months
# 6914      12-24 Months
# 5690      12-24 Months
# Name: Tenure Cohort, dtype: object

# %%
#didplay a scatter plot of the monthly charges agaisnt total charges with a hue of  Tenure Cohort
plt.figure(figsize=(10,4), dpi=200)
sns.scatterplot(data=data_transformed, x='MonthlyCharges', y='TotalCharges', hue='Tenure Cohort',
               alpha=0.4, linewidth=0.3);

# %%
#we can clearly see that the total charges are highest for the people who stay for more than 48 months, 
#followed by people who stay between 24-48 months then 12-24 months
#and lowest for people who stay less than 12 months

# %% [markdown]
# **A count plot showing the churn count per cohort.**

# %%
plt.figure(figsize=(9,6), dpi=200)
sns.countplot(data=data_transformed, x='Tenure Cohort', hue='Churn_Yes');

# %%
#its claer that most people who have stayed on the service for long are not likely to churn

# %% [markdown]
# ## 5.0 Data Preprocessing
# **Here we look at separating features and the label column and converting categorical features into numerical**

# %%
#convert the tenure cohort column to numeric for modeling
Tenure_Cohort_numeric = pd.get_dummies(data_transformed['Tenure Cohort'], prefix='Tenure Cohort',drop_first=True)
data_transformed = pd.concat([data_transformed,Tenure_Cohort_numeric], axis=1)
data_transformed = data_transformed.drop('Tenure Cohort', axis=1)

# %%
#Separate out the data into X features and Y label and the CustomerID sinec it wont be useful in modeling
X = data_transformed.drop(['Churn_Yes'], axis=1)
y = data_transformed['Churn_Yes']
X.sample(3)
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges  gender_Male  \
# 2893              0       6           63.40        348.80            0
# 5039              0      39           73.15       2730.85            1
# 3035              0      71          108.60       7690.90            1
#
#       Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 2893            0               0                 0
# 5039            0               0                 1
# 3035            1               0                 1
#
#       MultipleLines_No phone service  MultipleLines_Yes  ...  \
# 2893                               1                  0  ...
# 5039                               0                  1  ...
# 3035                               0                  1  ...
#
#       StreamingMovies_Yes  Contract_One year  Contract_Two year  \
# 2893                    1                  0                  1
# 5039                    0                  0                  0
# 3035                    1                  0                  1
#
#       PaperlessBilling_Yes  PaymentMethod_Credit card (automatic)  \
# 2893                     1                                      0
# 5039                     1                                      1
# 3035                     1                                      1
#
#       PaymentMethod_Electronic check  PaymentMethod_Mailed check  \
# 2893                               0                           1
# 5039                               0                           0
# 3035                               0                           0
#
#       Tenure Cohort_12-24 Months  Tenure Cohort_24-48 Months  \
# 2893                           0                           0
# 5039                           0                           1
# 3035                           0                           0
#
#       Tenure Cohort_Over 48 Months
# 2893                             0
# 5039                             0
# 3035                             1
#
# [3 rows x 33 columns]

# %% [markdown]
# **Feature Selection**
#
# Here we try to remove multicolliniarity by removing he highly correlated features. A correlation with an absolute value around 0.7-0.8 or higher is considered a high correlation. In our case  we take 0.75 as a cut-off and see how many high correlations we have.

# %%
#make a copy of the predictors data- X
X1 = X.copy()
#generate a correlation matrix and display if the
#correlation is >0.75
abs(X1.corr()) > 0.75
# Out:
#                                        SeniorCitizen  tenure  MonthlyCharges  \
# SeniorCitizen                                   True   False           False
# tenure                                         False    True           False
# MonthlyCharges                                 False   False            True
# TotalCharges                                   False    True           False
# gender_Male                                    False   False           False
# Partner_Yes                                    False   False           False
# Dependents_Yes                                 False   False           False
# PhoneService_Yes                               False   False           False
# MultipleLines_No phone service                 False   False           False
# MultipleLines_Yes                              False   False           False
# InternetService_Fiber optic                    False   False            True
# InternetService_No                             False   False            True
# OnlineSecurity_No internet service             False   False            True
# OnlineSecurity_Yes                             False   False           False
# OnlineBackup_No internet service               False   False            True
# OnlineBackup_Yes                               False   False           False
# DeviceProtection_No internet service           False   False            True
# DeviceProtection_Yes                           False   False           False
# TechSupport_No internet service                False   False            True
# TechSupport_Yes                                False   False           False
# StreamingTV_No internet service                False   False            True
# StreamingTV_Yes                                False   False           False
# StreamingMovies_No internet service            False   False            True
# StreamingMovies_Yes                            False   False           False
# Contract_One year                              False   False           False
# Contract_Two year                              False   False           False
# PaperlessBilling_Yes                           False   False           False
# PaymentMethod_Credit card (automatic)          False   False           False
# PaymentMethod_Electronic check                 False   False           False
# PaymentMethod_Mailed check                     False   False           False
# Tenure Cohort_12-24 Months                     False   False           False
# Tenure Cohort_24-48 Months                     False   False           False
# Tenure Cohort_Over 48 Months                   False    True           False
#
#                                        TotalCharges  gender_Male  Partner_Yes  \
# SeniorCitizen                                 False        False        False
# tenure                                         True        False        False
# MonthlyCharges                                False        False        False
# TotalCharges                                   True        False        False
# gender_Male                                   False         True        False
# Partner_Yes                                   False        False         True
# Dependents_Yes                                False        False        False
# PhoneService_Yes                              False        False        False
# MultipleLines_No phone service                False        False        False
# MultipleLines_Yes                             False        False        False
# InternetService_Fiber optic                   False        False        False
# InternetService_No                            False        False        False
# OnlineSecurity_No internet service            False        False        False
# OnlineSecurity_Yes                            False        False        False
# OnlineBackup_No internet service              False        False        False
# OnlineBackup_Yes                              False        False        False
# DeviceProtection_No internet service          False        False        False
# DeviceProtection_Yes                          False        False        False
# TechSupport_No internet service               False        False        False
# TechSupport_Yes                               False        False        False
# StreamingTV_No internet service               False        False        False
# StreamingTV_Yes                               False        False        False
# StreamingMovies_No internet service           False        False        False
# StreamingMovies_Yes                           False        False        False
# Contract_One year                             False        False        False
# Contract_Two year                             False        False        False
# PaperlessBilling_Yes                          False        False        False
# PaymentMethod_Credit card (automatic)         False        False        False
# PaymentMethod_Electronic check                False        False        False
# PaymentMethod_Mailed check                    False        False        False
# Tenure Cohort_12-24 Months                    False        False        False
# Tenure Cohort_24-48 Months                    False        False        False
# Tenure Cohort_Over 48 Months                  False        False        False
#
#                                        Dependents_Yes  PhoneService_Yes  \
# SeniorCitizen                                   False             False
# tenure                                          False             False
# MonthlyCharges                                  False             False
# TotalCharges                                    False             False
# gender_Male                                     False             False
# Partner_Yes                                     False             False
# Dependents_Yes                                   True             False
# PhoneService_Yes                                False              True
# MultipleLines_No phone service                  False              True
# MultipleLines_Yes                               False             False
# InternetService_Fiber optic                     False             False
# InternetService_No                              False             False
# OnlineSecurity_No internet service              False             False
# OnlineSecurity_Yes                              False             False
# OnlineBackup_No internet service                False             False
# OnlineBackup_Yes                                False             False
# DeviceProtection_No internet service            False             False
# DeviceProtection_Yes                            False             False
# TechSupport_No internet service                 False             False
# TechSupport_Yes                                 False             False
# StreamingTV_No internet service                 False             False
# StreamingTV_Yes                                 False             False
# StreamingMovies_No internet service             False             False
# StreamingMovies_Yes                             False             False
# Contract_One year                               False             False
# Contract_Two year                               False             False
# PaperlessBilling_Yes                            False             False
# PaymentMethod_Credit card (automatic)           False             False
# PaymentMethod_Electronic check                  False             False
# PaymentMethod_Mailed check                      False             False
# Tenure Cohort_12-24 Months                      False             False
# Tenure Cohort_24-48 Months                      False             False
# Tenure Cohort_Over 48 Months                    False             False
#
#                                        MultipleLines_No phone service  \
# SeniorCitizen                                                   False
# tenure                                                          False
# MonthlyCharges                                                  False
# TotalCharges                                                    False
# gender_Male                                                     False
# Partner_Yes                                                     False
# Dependents_Yes                                                  False
# PhoneService_Yes                                                 True
# MultipleLines_No phone service                                   True
# MultipleLines_Yes                                               False
# InternetService_Fiber optic                                     False
# InternetService_No                                              False
# OnlineSecurity_No internet service                              False
# OnlineSecurity_Yes                                              False
# OnlineBackup_No internet service                                False
# OnlineBackup_Yes                                                False
# DeviceProtection_No internet service                            False
# DeviceProtection_Yes                                            False
# TechSupport_No internet service                                 False
# TechSupport_Yes                                                 False
# StreamingTV_No internet service                                 False
# StreamingTV_Yes                                                 False
# StreamingMovies_No internet service                             False
# StreamingMovies_Yes                                             False
# Contract_One year                                               False
# Contract_Two year                                               False
# PaperlessBilling_Yes                                            False
# PaymentMethod_Credit card (automatic)                           False
# PaymentMethod_Electronic check                                  False
# PaymentMethod_Mailed check                                      False
# Tenure Cohort_12-24 Months                                      False
# Tenure Cohort_24-48 Months                                      False
# Tenure Cohort_Over 48 Months                                    False
#
#                                        MultipleLines_Yes  ...  \
# SeniorCitizen                                      False  ...
# tenure                                             False  ...
# MonthlyCharges                                     False  ...
# TotalCharges                                       False  ...
# gender_Male                                        False  ...
# Partner_Yes                                        False  ...
# Dependents_Yes                                     False  ...
# PhoneService_Yes                                   False  ...
# MultipleLines_No phone service                     False  ...
# MultipleLines_Yes                                   True  ...
# InternetService_Fiber optic                        False  ...
# InternetService_No                                 False  ...
# OnlineSecurity_No internet service                 False  ...
# OnlineSecurity_Yes                                 False  ...
# OnlineBackup_No internet service                   False  ...
# OnlineBackup_Yes                                   False  ...
# DeviceProtection_No internet service               False  ...
# DeviceProtection_Yes                               False  ...
# TechSupport_No internet service                    False  ...
# TechSupport_Yes                                    False  ...
# StreamingTV_No internet service                    False  ...
# StreamingTV_Yes                                    False  ...
# StreamingMovies_No internet service                False  ...
# StreamingMovies_Yes                                False  ...
# Contract_One year                                  False  ...
# Contract_Two year                                  False  ...
# PaperlessBilling_Yes                               False  ...
# PaymentMethod_Credit card (automatic)              False  ...
# PaymentMethod_Electronic check                     False  ...
# PaymentMethod_Mailed check                         False  ...
# Tenure Cohort_12-24 Months                         False  ...
# Tenure Cohort_24-48 Months                         False  ...
# Tenure Cohort_Over 48 Months                       False  ...
#
#                                        StreamingMovies_Yes  Contract_One year  \
# SeniorCitizen                                        False              False
# tenure                                               False              False
# MonthlyCharges                                       False              False
# TotalCharges                                         False              False
# gender_Male                                          False              False
# Partner_Yes                                          False              False
# Dependents_Yes                                       False              False
# PhoneService_Yes                                     False              False
# MultipleLines_No phone service                       False              False
# MultipleLines_Yes                                    False              False
# InternetService_Fiber optic                          False              False
# InternetService_No                                   False              False
# OnlineSecurity_No internet service                   False              False
# OnlineSecurity_Yes                                   False              False
# OnlineBackup_No internet service                     False              False
# OnlineBackup_Yes                                     False              False
# DeviceProtection_No internet service                 False              False
# DeviceProtection_Yes                                 False              False
# TechSupport_No internet service                      False              False
# TechSupport_Yes                                      False              False
# StreamingTV_No internet service                      False              False
# StreamingTV_Yes                                      False              False
# StreamingMovies_No internet service                  False              False
# StreamingMovies_Yes                                   True              False
# Contract_One year                                    False               True
# Contract_Two year                                    False              False
# PaperlessBilling_Yes                                 False              False
# PaymentMethod_Credit card (automatic)                False              False
# PaymentMethod_Electronic check                       False              False
# PaymentMethod_Mailed check                           False              False
# Tenure Cohort_12-24 Months                           False              False
# Tenure Cohort_24-48 Months                           False              False
# Tenure Cohort_Over 48 Months                         False              False
#
#                                        Contract_Two year  \
# SeniorCitizen                                      False
# tenure                                             False
# MonthlyCharges                                     False
# TotalCharges                                       False
# gender_Male                                        False
# Partner_Yes                                        False
# Dependents_Yes                                     False
# PhoneService_Yes                                   False
# MultipleLines_No phone service                     False
# MultipleLines_Yes                                  False
# InternetService_Fiber optic                        False
# InternetService_No                                 False
# OnlineSecurity_No internet service                 False
# OnlineSecurity_Yes                                 False
# OnlineBackup_No internet service                   False
# OnlineBackup_Yes                                   False
# DeviceProtection_No internet service               False
# DeviceProtection_Yes                               False
# TechSupport_No internet service                    False
# TechSupport_Yes                                    False
# StreamingTV_No internet service                    False
# StreamingTV_Yes                                    False
# StreamingMovies_No internet service                False
# StreamingMovies_Yes                                False
# Contract_One year                                  False
# Contract_Two year                                   True
# PaperlessBilling_Yes                               False
# PaymentMethod_Credit card (automatic)              False
# PaymentMethod_Electronic check                     False
# PaymentMethod_Mailed check                         False
# Tenure Cohort_12-24 Months                         False
# Tenure Cohort_24-48 Months                         False
# Tenure Cohort_Over 48 Months                       False
#
#                                        PaperlessBilling_Yes  \
# SeniorCitizen                                         False
# tenure                                                False
# MonthlyCharges                                        False
# TotalCharges                                          False
# gender_Male                                           False
# Partner_Yes                                           False
# Dependents_Yes                                        False
# PhoneService_Yes                                      False
# MultipleLines_No phone service                        False
# MultipleLines_Yes                                     False
# InternetService_Fiber optic                           False
# InternetService_No                                    False
# OnlineSecurity_No internet service                    False
# OnlineSecurity_Yes                                    False
# OnlineBackup_No internet service                      False
# OnlineBackup_Yes                                      False
# DeviceProtection_No internet service                  False
# DeviceProtection_Yes                                  False
# TechSupport_No internet service                       False
# TechSupport_Yes                                       False
# StreamingTV_No internet service                       False
# StreamingTV_Yes                                       False
# StreamingMovies_No internet service                   False
# StreamingMovies_Yes                                   False
# Contract_One year                                     False
# Contract_Two year                                     False
# PaperlessBilling_Yes                                   True
# PaymentMethod_Credit card (automatic)                 False
# PaymentMethod_Electronic check                        False
# PaymentMethod_Mailed check                            False
# Tenure Cohort_12-24 Months                            False
# Tenure Cohort_24-48 Months                            False
# Tenure Cohort_Over 48 Months                          False
#
#                                        PaymentMethod_Credit card (automatic)  \
# SeniorCitizen                                                          False
# tenure                                                                 False
# MonthlyCharges                                                         False
# TotalCharges                                                           False
# gender_Male                                                            False
# Partner_Yes                                                            False
# Dependents_Yes                                                         False
# PhoneService_Yes                                                       False
# MultipleLines_No phone service                                         False
# MultipleLines_Yes                                                      False
# InternetService_Fiber optic                                            False
# InternetService_No                                                     False
# OnlineSecurity_No internet service                                     False
# OnlineSecurity_Yes                                                     False
# OnlineBackup_No internet service                                       False
# OnlineBackup_Yes                                                       False
# DeviceProtection_No internet service                                   False
# DeviceProtection_Yes                                                   False
# TechSupport_No internet service                                        False
# TechSupport_Yes                                                        False
# StreamingTV_No internet service                                        False
# StreamingTV_Yes                                                        False
# StreamingMovies_No internet service                                    False
# StreamingMovies_Yes                                                    False
# Contract_One year                                                      False
# Contract_Two year                                                      False
# PaperlessBilling_Yes                                                   False
# PaymentMethod_Credit card (automatic)                                   True
# PaymentMethod_Electronic check                                         False
# PaymentMethod_Mailed check                                             False
# Tenure Cohort_12-24 Months                                             False
# Tenure Cohort_24-48 Months                                             False
# Tenure Cohort_Over 48 Months                                           False
#
#                                        PaymentMethod_Electronic check  \
# SeniorCitizen                                                   False
# tenure                                                          False
# MonthlyCharges                                                  False
# TotalCharges                                                    False
# gender_Male                                                     False
# Partner_Yes                                                     False
# Dependents_Yes                                                  False
# PhoneService_Yes                                                False
# MultipleLines_No phone service                                  False
# MultipleLines_Yes                                               False
# InternetService_Fiber optic                                     False
# InternetService_No                                              False
# OnlineSecurity_No internet service                              False
# OnlineSecurity_Yes                                              False
# OnlineBackup_No internet service                                False
# OnlineBackup_Yes                                                False
# DeviceProtection_No internet service                            False
# DeviceProtection_Yes                                            False
# TechSupport_No internet service                                 False
# TechSupport_Yes                                                 False
# StreamingTV_No internet service                                 False
# StreamingTV_Yes                                                 False
# StreamingMovies_No internet service                             False
# StreamingMovies_Yes                                             False
# Contract_One year                                               False
# Contract_Two year                                               False
# PaperlessBilling_Yes                                            False
# PaymentMethod_Credit card (automatic)                           False
# PaymentMethod_Electronic check                                   True
# PaymentMethod_Mailed check                                      False
# Tenure Cohort_12-24 Months                                      False
# Tenure Cohort_24-48 Months                                      False
# Tenure Cohort_Over 48 Months                                    False
#
#                                        PaymentMethod_Mailed check  \
# SeniorCitizen                                               False
# tenure                                                      False
# MonthlyCharges                                              False
# TotalCharges                                                False
# gender_Male                                                 False
# Partner_Yes                                                 False
# Dependents_Yes                                              False
# PhoneService_Yes                                            False
# MultipleLines_No phone service                              False
# MultipleLines_Yes                                           False
# InternetService_Fiber optic                                 False
# InternetService_No                                          False
# OnlineSecurity_No internet service                          False
# OnlineSecurity_Yes                                          False
# OnlineBackup_No internet service                            False
# OnlineBackup_Yes                                            False
# DeviceProtection_No internet service                        False
# DeviceProtection_Yes                                        False
# TechSupport_No internet service                             False
# TechSupport_Yes                                             False
# StreamingTV_No internet service                             False
# StreamingTV_Yes                                             False
# StreamingMovies_No internet service                         False
# StreamingMovies_Yes                                         False
# Contract_One year                                           False
# Contract_Two year                                           False
# PaperlessBilling_Yes                                        False
# PaymentMethod_Credit card (automatic)                       False
# PaymentMethod_Electronic check                              False
# PaymentMethod_Mailed check                                   True
# Tenure Cohort_12-24 Months                                  False
# Tenure Cohort_24-48 Months                                  False
# Tenure Cohort_Over 48 Months                                False
#
#                                        Tenure Cohort_12-24 Months  \
# SeniorCitizen                                               False
# tenure                                                      False
# MonthlyCharges                                              False
# TotalCharges                                                False
# gender_Male                                                 False
# Partner_Yes                                                 False
# Dependents_Yes                                              False
# PhoneService_Yes                                            False
# MultipleLines_No phone service                              False
# MultipleLines_Yes                                           False
# InternetService_Fiber optic                                 False
# InternetService_No                                          False
# OnlineSecurity_No internet service                          False
# OnlineSecurity_Yes                                          False
# OnlineBackup_No internet service                            False
# OnlineBackup_Yes                                            False
# DeviceProtection_No internet service                        False
# DeviceProtection_Yes                                        False
# TechSupport_No internet service                             False
# TechSupport_Yes                                             False
# StreamingTV_No internet service                             False
# StreamingTV_Yes                                             False
# StreamingMovies_No internet service                         False
# StreamingMovies_Yes                                         False
# Contract_One year                                           False
# Contract_Two year                                           False
# PaperlessBilling_Yes                                        False
# PaymentMethod_Credit card (automatic)                       False
# PaymentMethod_Electronic check                              False
# PaymentMethod_Mailed check                                  False
# Tenure Cohort_12-24 Months                                   True
# Tenure Cohort_24-48 Months                                  False
# Tenure Cohort_Over 48 Months                                False
#
#                                        Tenure Cohort_24-48 Months  \
# SeniorCitizen                                               False
# tenure                                                      False
# MonthlyCharges                                              False
# TotalCharges                                                False
# gender_Male                                                 False
# Partner_Yes                                                 False
# Dependents_Yes                                              False
# PhoneService_Yes                                            False
# MultipleLines_No phone service                              False
# MultipleLines_Yes                                           False
# InternetService_Fiber optic                                 False
# InternetService_No                                          False
# OnlineSecurity_No internet service                          False
# OnlineSecurity_Yes                                          False
# OnlineBackup_No internet service                            False
# OnlineBackup_Yes                                            False
# DeviceProtection_No internet service                        False
# DeviceProtection_Yes                                        False
# TechSupport_No internet service                             False
# TechSupport_Yes                                             False
# StreamingTV_No internet service                             False
# StreamingTV_Yes                                             False
# StreamingMovies_No internet service                         False
# StreamingMovies_Yes                                         False
# Contract_One year                                           False
# Contract_Two year                                           False
# PaperlessBilling_Yes                                        False
# PaymentMethod_Credit card (automatic)                       False
# PaymentMethod_Electronic check                              False
# PaymentMethod_Mailed check                                  False
# Tenure Cohort_12-24 Months                                  False
# Tenure Cohort_24-48 Months                                   True
# Tenure Cohort_Over 48 Months                                False
#
#                                        Tenure Cohort_Over 48 Months
# SeniorCitizen                                                 False
# tenure                                                         True
# MonthlyCharges                                                False
# TotalCharges                                                  False
# gender_Male                                                   False
# Partner_Yes                                                   False
# Dependents_Yes                                                False
# PhoneService_Yes                                              False
# MultipleLines_No phone service                                False
# MultipleLines_Yes                                             False
# InternetService_Fiber optic                                   False
# InternetService_No                                            False
# OnlineSecurity_No internet service                            False
# OnlineSecurity_Yes                                            False
# OnlineBackup_No internet service                              False
# OnlineBackup_Yes                                              False
# DeviceProtection_No internet service                          False
# DeviceProtection_Yes                                          False
# TechSupport_No internet service                               False
# TechSupport_Yes                                               False
# StreamingTV_No internet service                               False
# StreamingTV_Yes                                               False
# StreamingMovies_No internet service                           False
# StreamingMovies_Yes                                           False
# Contract_One year                                             False
# Contract_Two year                                             False
# PaperlessBilling_Yes                                          False
# PaymentMethod_Credit card (automatic)                         False
# PaymentMethod_Electronic check                                False
# PaymentMethod_Mailed check                                    False
# Tenure Cohort_12-24 Months                                    False
# Tenure Cohort_24-48 Months                                    False
# Tenure Cohort_Over 48 Months                                   True
#
# [33 rows x 33 columns]

# %%
# save absolute value of correlation matrix as a data frame
# convert all values to absolute value
# stack the row:column pairs into a multindex
# reset the index to set the multindex to seperate columns
# sort values. 0 is the column automatically generated by the stacking


df=X1.corr().abs().stack().reset_index().sort_values(0, ascending=False)

# zip the variable name columns (Which were only named level_0 and level_1 by default) in a new column named "pairs"
df['pairs'] = list(zip(df.level_0, df.level_1))

# set index to pairs
df.set_index(['pairs'], inplace = True)

#d rop level columns
df.drop(columns=['level_1', 'level_0'], inplace = True)

# rename correlation column as cc rather than 0
df.columns = ['cc']

# drop duplicates. This could be dangerous if you have variables perfectly correlated with variables other than themselves.
# for the sake of exercise, kept it in.
df.drop_duplicates(inplace=True)

# %%
#check the dataframe correlation and exclude the 
#feature correlation to itself
df = df[(df.cc>.75) & (df.cc <1)]
df
# Out:
#                                                          cc
# pairs
# (Tenure Cohort_Over 48 Months, tenure)             0.858930
# (tenure, TotalCharges)                             0.825880
# (InternetService_Fiber optic, MonthlyCharges)      0.787195
# (StreamingTV_No internet service, MonthlyCharges)  0.763191

# %%
#we needto drop one feature per the correlated pair, but from the plot of how features are correlated to the class label,
#all the other features seem to be of importance

features_todrop = ['StreamingTV_No internet service']
X = X.drop(features_todrop, axis=1)

# %%
# split data  into train and test
#import the train test split module
from sklearn.model_selection import train_test_split
#create a train_test_split with 80% train data since our dataset is quite small
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)
print("X_train:",X_train.shape)
print("y_train:", y_train.shape)
# Out:
# X_train: (5625, 32)
# y_train: (5625,)

# %% [markdown]
# ### Normalize the data using a standard scaler

# %%
#import a standard scaler
from sklearn.preprocessing import StandardScaler
#instantiate the scaler
scaler =  StandardScaler()
#fit and transform x_train
X_train = scaler.fit_transform(X_train)
#transform X_test
X_test = scaler.transform(X_test)

# %% [markdown]
# ## 6.0 Predictive Modeling
#
# **We wil explore 1 Logistic Regression and 5 different tree based methods: A Single Decision Tree, Random Forest, AdaBoost, XGBoost.**

# %% [markdown]
# ## Baseline Model
#
# ### Logistic Regression
# Logistic regression is used to estimate the probability of descrete values based on a given dataset of independent variables. Since the outcome is a probability, the dependent variable is bounded between 0 and 1. In logistic regression, a logit transformation is applied on the odds—that is, the probability of success divided by the probability of failure. This is also commonly known as the log odds, or the natural logarithm of odds. We will use it as our baseline model since It is very fast at classifying unknown records.

# %%
#import logistic model
from sklearn.linear_model import LogisticRegression
#instantiate a decision tree classifier
logreg = LogisticRegression()

#fit the model on the training data
logreg.fit(X_train, y_train)

#make predictions on test data
preds = logreg.predict(X_test)

# %%
#get the performance of the model using the classification report
print(classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.91      0.88      1052
#            1       0.66      0.54      0.59       355
#
#     accuracy                           0.81      1407
#    macro avg       0.76      0.72      0.74      1407
# weighted avg       0.81      0.81      0.81      1407

# %%
#get the performance of the model using by plotting the confusion metrix
plot_confusion_matrix(logreg, X_test, y_test);

# %%
# the model's overall accuracy good (81%), but its not doing quite well on classifying data as we have an F1 score of 88% 
#on the 0 class which has more data and  59% on the 1 clas which has less data. 
#We can look into more models to check for better accuracy of low variance.

# %% [markdown]
# ### K-Nearest Neighbors (KNN)
#
#  **We will build our second model off of the K-NeighborsClassifier with hyperparameter tuning and see if our performance improves**
#
# NN is a distance-based classifier, meaning that it implicitly assumes that the smaller the distance between two points, the more similar they are. In KNN, each column acts as a dimension.

# %%
# Import KNeighborsClassifier
from sklearn.neighbors import KNeighborsClassifier

# Instantiate KNeighborsClassifier
knn = KNeighborsClassifier()
#define the kvalues
k_values =list(range(1,30))

param_grid = dict(n_neighbors=k_values)

#instantiate gridsearch
grid = GridSearchCV(knn, param_grid, cv=10, scoring='accuracy', return_train_score=False,verbose=1)

# Fit the classifier
grid.fit(X_train, y_train)
#get the best estimators
grid.best_estimator_.get_params()
# Out:
# Fitting 10 folds for each of 29 candidates, totalling 290 fits
# {'algorithm': 'auto',
#  'leaf_size': 30,
#  'metric': 'minkowski',
#  'metric_params': None,
#  'n_jobs': None,
#  'n_neighbors': 24,
#  'p': 2,
#  'weights': 'uniform'}

# %%
#get the cv_results
pd.DataFrame(grid.cv_results_)['mean_test_score'].plot(marker = 'o')
plt.xlabel('K Values')
plt.ylabel('Mean Test Score')
plt.title('Accuracy Score Curve')
# Out:
# Text(0.5, 1.0, 'Accuracy Score Curve')

# %%
#this shows that when we increase our K value, the accuracy increases up until 25 when it starts to decrease

# %%
# Predict on the test set
preds = grid.predict(X_test)

# %%
#check the performance of the model using the classification report
print(classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.89      0.87      1052
#            1       0.61      0.52      0.56       355
#
#     accuracy                           0.80      1407
#    macro avg       0.73      0.70      0.71      1407
# weighted avg       0.79      0.80      0.79      1407

# %%
#get the performance of the model using by plotting the confusion metrix
plot_confusion_matrix(grid, X_test, y_test);

# %%
# A KNN model has reduced performance (80%) compared to the earlier model-the logistic regression that had an accuracy score of 81%
#the F1 score on the yes_churn class is also quite poor 56% and 87% for no churn
#We will try to use the Random Forest and see if our model performance improves

# %% [markdown]
# ### Random Forest
# Here we try to improve our second Model using a vanilla random Forest classifier.
# Random Forest is an ensemble technique capable of performing both regression and classification tasks with the use of multiple decision trees and a technique called Bootstrap and Aggregation, commonly known as bagging. The basic idea behind this is to combine multiple decision trees in determining the final output rather than relying on individual decision trees.Random forest has an advantage of low variance compared to decision tree.

# %%
# import the Random Forest classifier
from sklearn.ensemble import RandomForestClassifier

# %%
#instantiate the Random Forest Classifier
rf = RandomForestClassifier(n_estimators=50, max_features=10, max_depth=2, class_weight="balanced" )

#fit the model to the train data
rf.fit(X_train, y_train)

#make predictions
preds = rf.predict(X_test)

# %%
#get the performance of the model using the classification report
print(classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.70      0.79      1052
#            1       0.46      0.77      0.58       355
#
#     accuracy                           0.72      1407
#    macro avg       0.68      0.74      0.68      1407
# weighted avg       0.79      0.72      0.73      1407

# %%
#get the performance of the model using by plotting the confusion metrix
plot_confusion_matrix(rf, X_test, y_test);

# %%
#our model is performing poorly on the F1 score,but better than the decison tree. We have low precison on the 1 class but high recall leading to
#an F1 score of 58%. We will try a different model and see the resulsts

# %%
#check important features
imp_feats = pd.DataFrame(data=rf.feature_importances_,
                        index=X.columns,
                        columns=['Feat Imp'])

# %%
#plot features that have a weight greater than 0
imp_feats = imp_feats[imp_feats['Feat Imp']>0]
#sort_values in the data frame
imp_feats = imp_feats.sort_values('Feat Imp', ascending=False)
plt.figure(figsize=(14,6), dpi=200)
sns.barplot(data=imp_feats, x=imp_feats.index, y ='Feat Imp');
plt.xticks(rotation=90);

# %%
#the most important features in the dataframe according random forest classifier are :
#tenure,monthly charges, total charges, internetservice_fibre optic, tech_support, online_security, contract_type, payment method, cohort Tenure

# %%
#Visualisation of the model with one random tree.
#import tree
from sklearn import tree
# pick a specific tree from the forest
tree = rf.estimators_[24]
plt.figure(figsize=(12,12), dpi=500)
tree.plot_tree(tree, feature_names=X.columns,
               class_names=np.unique(y).astype('str'),
               filled=True, rounded=True)
plt.show()
# export_graphviz(
#         tree,
#         out_file="tree.dot",
#         feature_names = X.columns,
#         class_names=np.unique(y).astype('str'),
#         rounded=True,
#         filled=True
#     )
  
# # view = Source.from_file("tree.dot")
# # view.render('tree', format='jpg',view=True)
# # view.view()
# graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
# # graph.write_png('absenteism_forest.png')
# Image(graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15732\357024392.py in <module>
#       5 tree = rf.estimators_[24]
#       6 plt.figure(figsize=(12,12), dpi=500)
# ----> 7 tree.plot_tree(tree, feature_names=X.columns,
#       8                class_names=np.unique(y).astype('str'),
#       9                filled=True, rounded=True)
#
# AttributeError: 'DecisionTreeClassifier' object has no attribute 'plot_tree'

# %% [markdown]
# ### AdaBoost
# **Random forest didnt do quite well as it has a lot of misclassification. We venture to train and predict our data on Adaboost Model**
# AdaBoost is short for Adaptive Boosting and is a very popular boosting technique that combines multiple “weak classifiers” into a single “strong classifier”.

# %%
# import the Adaboost classifier
from sklearn.ensemble import AdaBoostClassifier

# %%
#instantiate the model

ada = AdaBoostClassifier(n_estimators=100)

#fit the model on the training data
ada.fit(X_train, y_train)

#make predictions
preds = ada.predict(X_test)

# %%
#get the performance of the model using the classification report
print(classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.90      0.88      1052
#            1       0.64      0.55      0.60       355
#
#     accuracy                           0.81      1407
#    macro avg       0.75      0.73      0.74      1407
# weighted avg       0.80      0.81      0.80      1407

# %%
#get the performance of the model using by plotting the confusion metrix
plot_confusion_matrix(ada, X_test, y_test);

# %%
#Adaboost has the best performance so far with an accuracy score of 84% with an F1 score of 60%. Our recall is generally still low we 
#will try out xGBoost to see if our recall will improve

# %% [markdown]
# ### XGBoost (eXtreme Gradient Boosting)
# XGBoost was designed basically to improve speed and model performance.

# %%
# import the XGBoost classifier
from xgboost import XGBClassifier

# %%
# instantiate the classifier
xgb = XGBClassifier()

# %%
#fit the traing data
xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
#make predictions
preds = xgb.predict(X_test)

# %%
#get the performance of the model using the classification report
print(classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.89      0.87      1052
#            1       0.61      0.51      0.56       355
#
#     accuracy                           0.79      1407
#    macro avg       0.73      0.70      0.71      1407
# weighted avg       0.78      0.79      0.79      1407

# %%
#get the performance of the model using by plotting the confusion metrix
plot_confusion_matrix(xgb, X_test, y_test);

# %%
#XGBoost a slightly lower than Adaboost accuracy- 79%  and an F1 score of 56% on our yes churn(1) class compred to 86 on the no nurn class(0). Our recall is generally still low we 
#will try out hyperparameter tuning to see if our recall will improve

# %% [markdown]
# ### XGBoost with class Balancing using SMOTE
# SMOTE creates new synthetic minority samples instead of copy pasting the already available data points.

# %%
# Smote oversampling

# import random undersampling library 
from collections import Counter
from imblearn.over_sampling import SMOTE
# summarize class distribution
print(Counter(y_train))

# define undersample strategy
SMOTE = SMOTE()

# fit and apply the transform
X_train_SMOTE, y_train_SMOTE = SMOTE.fit_resample(X_train, y_train)

# summarize class distribution
print(Counter(y_train_SMOTE))
# Out:
# Counter({0: 4111, 1: 1514})
# Counter({0: 4111, 1: 4111})

# %%
param_grid = {
    'learning_rate': [0.1, 0.2],
    'max_depth': [6],
    'min_child_weight': [1, 2],
    'subsample': [0.5, 0.7],
    'n_estimators': [50, 100, 200],
}

from sklearn.model_selection import GridSearchCV
grid_clf = GridSearchCV(xgb, param_grid, scoring='accuracy', cv=None, n_jobs=1)
grid_clf.fit(X_train_SMOTE, y_train_SMOTE)
best_parameters = grid_clf.best_params_
print('Grid Search found the following optimal parameters: ')
for param_name in sorted(best_parameters.keys()):
    print('%s: %r' % (param_name, best_parameters[param_name]))
preds = grid_clf.predict(X_test)
# Out:
# Grid Search found the following optimal parameters:
# learning_rate: 0.1
# max_depth: 6
# min_child_weight: 2
# n_estimators: 100
# subsample: 0.7

# %%
#get the performance of the model using the classification report
print(classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.86      0.86      1052
#            1       0.59      0.61      0.60       355
#
#     accuracy                           0.79      1407
#    macro avg       0.73      0.73      0.73      1407
# weighted avg       0.80      0.79      0.80      1407

# %%
plot_confusion_matrix(grid_clf, X_test, y_test);

# %%
# The F1 score now increase by 4% to 60%, but the accuracy score goes down by 1% 60 79%

# %% [markdown]
# **Random Forest with resampled data**

# %%
#instantiate the Random Forest Classifier
rf1 = RandomForestClassifier(n_estimators=50, max_features=10, max_depth=2)

#fit the model to the train data
rf1.fit(X_train_SMOTE, y_train_SMOTE)

#make predictions
preds = rf1.predict(X_test)

# %%
#get the performance of the model using the classification report
print(classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.70      0.79      1052
#            1       0.47      0.78      0.58       355
#
#     accuracy                           0.72      1407
#    macro avg       0.69      0.74      0.69      1407
# weighted avg       0.79      0.72      0.74      1407

# %%
plot_confusion_matrix(rf1, X_test, y_test);

# %%
# We dont notice any much change as we see the the F1 score for class 1 is still at 58%, but there is a decline in the accuracy score to 72%

# %% [markdown]
# **Adaboost with tuned parameters and resampled data**

# %%
from sklearn.model_selection import RepeatedStratifiedKFold
# defining the classifier
ada2 = AdaBoostClassifier()
# creating a dic for the grid
param_grid={'n_estimators': [10, 50, 100, 200, 500],
           'learning_rate':[0.0001, 0.01, 0.1, 1.0, 1.1, 1.2]}
# # defining the CV
# cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3)

# initializing the grid search
grid_search = GridSearchCV(estimator=ada2, param_grid=param_grid, n_jobs=-1, cv=None, scoring='accuracy')
# training the model on grid search for hyperparameter tuning of Adaboost
grid_search.fit(X_train_SMOTE, y_train_SMOTE)

# finding the best results /hyperparameter tuning of Adaboost
print("Best: %f using %s" % (grid_search.best_score_, grid_search.best_params_))

best_parameters = grid_search.best_params_
print('Grid Search found the following optimal parameters: ')
for param_name in sorted(best_parameters.keys()):
    print('%s: %r' % (param_name, best_parameters[param_name]))
#make predictisctions
preds = grid_search.predict(X_test)
# Out:
# Best: 0.836190 using {'learning_rate': 1.1, 'n_estimators': 200}
# Grid Search found the following optimal parameters:
# learning_rate: 1.1
# n_estimators: 200

# %%
#get the performance of the model using the classification report
print(classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.84      0.86      1052
#            1       0.57      0.66      0.61       355
#
#     accuracy                           0.79      1407
#    macro avg       0.73      0.75      0.74      1407
# weighted avg       0.80      0.79      0.80      1407

# %%
plot_confusion_matrix(grid_search, X_test, y_test);

# %%
# Our F1 score only improves by 1% after resampling and our accuracy score drops to 79% from 81%
